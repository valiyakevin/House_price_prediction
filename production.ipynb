# %%
import pickle 
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# assume user inputhape(1,9) 
#test_input1 = np.array([56,'Other','High','Divorced','Electronics',0.50,'Wednesday',411.13,52],dtype=object).reshape(1,9)


test_input1 = pd.DataFrame({
    'age': [56],
    'gender': ['Other'],
    'income_bracket': ['High'],
    'marital_status': ['Divorced'],
    'product_category': ['Electronics'],
    'discount_applied': [0.50],
    'day_of_week': ['Wednesday'],
    'avg_purchase_value': [411.13],
    'purchase_frequency': [52]
})

pipe.predict(test_input1)
# Out:
# array([3], dtype=int32)

# %%
pipe.predict(test_input1)
# Out:
# array([3], dtype=int32)
